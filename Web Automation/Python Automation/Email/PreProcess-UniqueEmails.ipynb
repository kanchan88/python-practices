# %%
import numpy as np
import pandas as pd

# %%
file = pd.read_excel('email.xlsx')

# %%
file
# Out:
#            anubhavkaphle@gmail.com
# 0            sunil.aryal@ieee.org,
# 1           bjupreti123@gmail.com,
# 2           sahranjit77@gmail.com,
# 3           m.khadka515@gmail.com,
# 4    samratshrestha4536@gmail.com,
# ..                             ...
# 127    regmi.prakriti24@gmail.com,
# 128             connect@anyesh.me,
# 129     bhattbhuwan13@outlook.com,
# 130       nimesgautam@outlook.com,
# 131   livessarusu-3553@yopmail.com
#
# [132 rows x 1 columns]

# %%
dat = []
for single in file['anubhavkaphle@gmail.com']:
    if(single[-1]==","):
        dat.append(single[0:-1])
    else:
        dat.append(single)

# %%
for single in file['anubhavkaphle@gmail.com']:
    print(single[0:-1])
# Out:
# sunil.aryal@ieee.org
# bjupreti123@gmail.com
# sahranjit77@gmail.com
# m.khadka515@gmail.com
# samratshrestha4536@gmail.com
# akushal84@gmail.com
# pouder0@sewanee.edu
# bhimrajyadav977@gmail.com
# pe.messh@gmail.com
# rjarun8@gmail.com
# bhusal.anish12@gmail.com
# khatrinishan123@gmail.com
# shrill.shrestha27@gmail.com
# st487@snu.edu.in
# ymilan361@gmail.com
# thinamjr@gmail.com
# sauravthakur1341@gmail.com
# acharyasabin1997@gmail.com
# samida226077@gmail.com
# ashwinkh7@gmail.com
# bijen.shrestha333@gmail.com
# shahid.faris786@gmail.com
# robbin.khatiwada@gmail.com
# gnoitanec@gmail.com
# poudelt75@gmail.com
# bhupinbaral.729@gmail.com
# ansible.nahakulatm@gmail.com
# mahaseth.aman123@gmail.com
# provii.sth@gmail.com
# aju.tamang@innovatetech.c
# pokhrel.nil@gmail.co
# shrestha.siddhartha06@outlook.co
# sangamkhnl@gmail.com
# nepaliamar1998@gmail.com
# roshanbasn3t@gmail.com
# dhurbabaralam@gmail.com
# saishab.bhattarai.01@gmail.com
# czansunar0098@gmail.com
# ...
